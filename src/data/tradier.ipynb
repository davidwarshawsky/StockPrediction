# %% [markdown]
# https://developer.tradier.com/getting_started
# https://documentation.tradier.com/brokerage-api/overview/market-data
# https://info.orats.com/dataapi?utm_campaign=Tradier&utm_source=email

# %%
import httplib

# Request: Market Quotes (https://sandbox.tradier.com/v1/markets/quotes?symbols=spy)

connection = httplib.HTTPSConnection('sandbox.tradier.com', 443, timeout = 30)

# Headers

headers = {"Accept":"application/json",
           "Authorization":"Bearer ASSXgYl15sWHMjDwDSs05myw9N26"}

# Send synchronously

connection.request('GET', '/v1/markets/quotes?symbols=spy', None, headers)
try:
  response = connection.getresponse()
  content = response.read()
  # Success
  print('Response status ' + str(response.status))
except httplib.HTTPException, e:
  # Exception
  print('Exception during request')

# %%
import requests

# %%
token =  'ASSXgYl15sWHMjDwDSs05myw9N26'
response = requests.get('https://sandbox.tradier.com/v1/markets/options/strikes',
    params={'symbol': 'AAPL', 'expiration': '2019-05-27'},
    headers={'Authorization': 'Bearer <ASSXgYl15sWHMjDwDSs05myw9N26>', 'Accept': 'application/json'}
)

# %%
import requests

 

response = requests.get('https://sandbox.tradier.com/v1/markets/options/expirations',

    params={'symbol': 'AMZN', 'includeAllRoots': 'false', 'strikes': 'true'},

    headers={'Authorization': 'Bearer 0OTsK4NA7XzXXE3mSk05sJls9WAj', 'Accept': 'application/json'}

)

json_response = response.json()

print(response.status_code)

print(json_response)
# Out:
# 200
# ...

# %%
from dictionary import JSON_Parser
parser = JSON_Parser(json_response)

# %%
expirations = json_response['expirations']['expiration'] 
lens = dict()
for x in expirations:
    lens[x['date']] = len(x['strikes']['strike'])
print(lens)
# Out:
# {'2020-07-17': 431, '2020-07-24': 307, '2020-07-31': 275, '2020-08-07': 244, '2020-08-14': 213, '2020-08-21': 345, '2020-08-28': 115, '2020-09-18': 290, '2020-10-16': 276, '2020-11-20': 118, '2021-01-15': 313, '2021-02-19': 254, '2021-06-18': 144, '2022-01-21': 178, '2022-06-17': 99}

# %%
from tradier import get_option_expirations
dates,strikes = get_options_expirations("AAPL")
print(dates)
print(strikes)
print(len(dates) == len(strikes))
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-46-c564375b9c60> in <module>
#       1 from tradier import get_option_expirations
# ----> 2 dates,strikes = get_options_expirations("AAPL")
#       3 print(dates)
#       4 print(strikes)
#       5 print(len(dates) == len(strikes))
#
# NameError: name 'get_options_expirations' is not defined

# %%
api_key = 'Bearer 0OTsK4NA7XzXXE3mSk05sJls9WAj'

# %%
import requests

response = requests.get('https://sandbox.tradier.com/v1/markets/options/strikes',
    params={'symbol': 'AAPL', 'expiration': '2020-05-12'},
    headers={'Authorization': api_key, 'Accept': 'application/json'}
)
json_response = response.json()
print(response.status_code)
print(json_response)
# print(json_response['strikes']['strike'])
# Out:
# 200
# {'strikes': None}
